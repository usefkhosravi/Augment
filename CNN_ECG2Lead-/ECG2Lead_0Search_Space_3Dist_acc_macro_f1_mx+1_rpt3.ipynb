# %% [markdown]
# import time
# plc=1
# time.sleep(1500*plc)         #run after 1 houre = 3600 seconds

# %%
import os
import glob
import scipy
import random
import bisect
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import signal
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
from preprocess import *                         #ماژول استخراج پنجره ها
from data import *                          #ماژول محلی ورود داده ها
from augment import *                            #ماژول های داده افزایی
from lstm_cnn import *                           #ماژول های داده افزایی با lstm_cnn
import augment
import importlib
importlib.reload(augment)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report,recall_score,precision_score
from tensorflow.keras import callbacks
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,Conv1D,Dropout,MaxPooling1D,MaxPooling2D,Flatten,Dense
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
cwd = os.getcwd() #
fullscrn()
# Out:
# <style>#notebook { padding-top:0px !important; } .container { width:100% !important; } .end_space { min-height:0px !important; } html, body, .container{ margin:0!important;padding:0!important;}</style>

# %%
def maxindx(ar):
    ar_cpy=np.array(ar)
    pred=np.argmax(ar,axis=1)
    for i in range (len(pred)):
        if pred[i]==0:
            ar_cpy[i,0]=-1000
    pred=np.argmax(ar_cpy,axis=1)
    return(pred)

# %% [markdown]
# <h1><center><div style="direction:rtl;font-family:B Nazanin">Importing Data</div></center></h1>

# %%
cls_num=2
for i in range (1,cls_num+1):
    vars()['ecg'+str(i)],vars()['ecg_tst'+str(i)]=TwoLeadECG(i)
os.chdir(cwd)
clses_lens=np.array([])
i=0                               #جمع آوری داده ها و چاپ تعداد نمونه ی هر کلاس
ecg=np.array(ecg1)
print(1,len(vars()['ecg'+str(1)]), end='\t')
clses_lens=np.append(clses_lens,len(vars()['ecg'+str(1)]))
for i in range (2,cls_num+1):
    ecg=np.concatenate((ecg,vars()['ecg'+str(i)]),axis=0)
    clses_lens=np.append(clses_lens,len(vars()['ecg'+str(i)]))
    print( i,len(vars()['ecg'+str(i)]), end='\t')

mx_sig=max(clses_lens)
print('shape ecg=',np.shape(ecg))
# Out:
# first_train_shape= (23, 83)
# first_test_shape= (1139, 83)
# classes_quantity= 2
# tr_lbls=	 {1, 2}
# Count_labels= [12 11]
# max(train_feature_Altitude)= 2.0
# min(train_feature_Altitude)= -3.1489147
# first_train_sample=
#  [ 2.          0.68834554  0.6172271   0.6172271   0.56981481  0.68834554
#   0.64093325  0.71205169  0.78317013  0.49869637  0.47499023  0.54610867
#   0.33275335  0.33275335  0.26163491  0.23792876  0.26163491  0.21422262
#   0.21422262  0.26163491  0.23792876  0.09569189  0.11939803  0.11939803
#  -0.02283885  0.16681032  0.28534105  0.16681032  0.04827959  0.16681032
#   0.16681032  0.14310418 -0.80514168 -2.1800981  -3.0098133  -3.0098133
#  -2.8438703  -2.962401   -2.5831026  -2.0378613  -2.0852736  -1.8482121
#  -1.4689138  -1.2318524  -1.1370278  -0.6629048  -0.37843104 -0.33101875
#  -0.14136958  0.28534105  0.45128408  0.49869637  0.40387178  0.33275335
#   0.47499023  0.28534105  0.42757794  0.49869637  0.6172271   0.54610867
#   0.49869637  0.54610867  0.6172271   0.6646394   0.6646394   0.71205169
#   0.80687628  0.78317013  0.85428856  0.80687628  0.90170086  0.85428856
#   0.73575783  0.71205169  0.64093325  0.56981481  0.45128408  0.40387178
#   0.35645949  0.21422262  0.14310418  0.16681032  0.14310418]
# 1 12	2 11	shape ecg= (23, 481)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %% [markdown]
# <h2><center><div style="direction:rtl;font-family:B Nazanin">Base Train windows</div></center></h1>

# %%
smpl_rte=480                                              # در ماژول ها نیز همین مقدار ثبت شده
i=0
windws=np.array([])

for cls in range (1,cls_num+1):                                 #ساخت پنجره های داده های آموزش اصلی
    vars()['wndws'+str(cls)]=np.array(vars()['ecg'+str(cls)])  
    
print("each class and its windows =")

cls_wndws=np.array([])
for cls in range (1,cls_num+1):                                # آرایه ی تعداد پنجره ی هر کلاس
    wns=len(vars()['wndws'+str(cls)])
    cls_wndws=np.append(cls_wndws,wns)
    print(cls, wns, end='\t')

mx_wndws=int(np.max(cls_wndws))                        # حداکثر تعداد پنجره ی موجود بین کلاس ها
print('\n max =', mx_wndws)
# Out:
# each class and its windows =
# 1 12	2 11
#  max = 12

# %%
#clses=3                                   #تعیین میزان افزایش نمونه (تولید داده)
mx_wndws=int(mx_wndws+1)  #mx_wndws*0.3  # =classes-1 برای بررسی الگوریتم تعداد کمی کلاس آزمایش شد
print(mx_wndws)
# Out:
# 13

# %% [markdown]
# <h1><center><div style="direction:rtl;font-family:B Nazanin">Data Augmentation</div></center></h1>

# %%
for method in range(10,70,10):
    print(method)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60

# %%
rpt_cnn_clsfctn=3
rslt=np.array([])
rslts=np.array([])
for methd in range(10,80,10):
    for quality in range(1,7):
        if quality==1:
            sort=-5          #-5=Dis_sam_Cls=qlty1   #-4=var_Dis=qlty2    #-3=DisSm/DisOthr=qlty3    #-2=invrs_GDO_papr=qlty4   #-1=GDO_papr=qlty5  
            invers=0         #1=inverse sorting base of "sort"             #inverse of qlity3=qlty6  else=0
        elif quality==2:
            sort=-4          #-5=Dis_sam_Cls=qlty1   #-4=var_Dis=qlty2    #-3=DisSm/DisOthr=qlty3    #-2=invrs_GDO_papr=qlty4   #-1=GDO_papr=qlty5  
            invers=0         #1=inverse sorting base of "sort"             #inverse of qlity3=qlty6  else=0
        elif quality==3:
            sort=-3          #-5=Dis_sam_Cls=qlty1   #-4=var_Dis=qlty2    #-3=DisSm/DisOthr=qlty3    #-2=invrs_GDO_papr=qlty4   #-1=GDO_papr=qlty5  
            invers=0         #1=inverse sorting base of "sort"             #inverse of qlity3=qlty6  else=0
        elif quality==4:
            sort=-2          #-5=Dis_sam_Cls=qlty1   #-4=var_Dis=qlty2    #-3=DisSm/DisOthr=qlty3    #-2=invrs_GDO_papr=qlty4   #-1=GDO_papr=qlty5  
            invers=0         #1=inverse sorting base of "sort"             #inverse of qlity3=qlty6  else=0
        elif quality==5:
            sort=-1          #-5=Dis_sam_Cls=qlty1   #-4=var_Dis=qlty2    #-3=DisSm/DisOthr=qlty3    #-2=invrs_GDO_papr=qlty4   #-1=GDO_papr=qlty5  
            invers=0         #1=inverse sorting base of "sort"             #inverse of qlity3=qlty6  else=0
        else :
            sort=-3          #-5=Dis_sam_Cls=qlty1   #-4=var_Dis=qlty2    #-3=DisSm/DisOthr=qlty3    #-2=invrs_GDO_papr=qlty4   #-1=GDO_papr=qlty5  
            invers=1         #1=inverse sorting base of "sort"             #inverse of qlity3=qlty6  else=0
        for dp_slct_dstrb in range (1,6):#1-sequencial 2-linear 3-beta 4-exponential 5-unfrm
            rprt=np.empty((0,3),float)
            for repeat in range(1,rpt_cnn_clsfctn+1):
                for i in range (1,cls_num+1):                           #تعریف آرایه ی پنجره های کلاس ها
                    vars()['ecg_aug'+str(i)+str(methd)]=np.empty((0,smpl_rte+1), float) 
                for i in range (1,cls_num+1):                                     #تعریف آرایه ی پنجره های کلاس ها
                    vlum_win=mx_wndws-len(vars()['wndws'+str(i)])         #میزان داده افزایی در روش های عمیق (پنجره)
                    #print("vlum_win=",vlum_win)
                    vars()['ecg_aug'+str(i)+str(methd)]=np.append(vars()['ecg_aug'+str(i)+str(methd)],srtd_data(methd,i,vlum_win,dp_slct_dstrb,sort),axis=0)
                    #print('aug shape=',np.shape(scl_rndm(ecg,i,vlum_win,mag=.1)))
                    #print('generated data shape for class ', i, ' = ', np.shape(vars()['ecg_aug'+str(i)+str(methd)]))

                #add augmented data to base data
                xtrain=np.empty((0,smpl_rte+1), float) 
                for i in range (1,cls_num+1):   
                    xtrain=np.append(xtrain,vars()['wndws'+str(i)],axis=0)
                    xtrain=np.append(xtrain,vars()['ecg_aug'+str(i)+str(methd)],axis=0)
                    #print('Up to class ', i, 'train shape = ', np.shape(xtrain))

                # Normalization train windows
                mx_aug=np.max(xtrain[:,:-1])
                mx=np.max(ecg[:,:-1])
                mn_aug=np.min(xtrain[:,:-1])
                mn=np.min(ecg[:,:-1])
                xtrain[:,:-1]= 2*(xtrain[:,:-1]-mn_aug)/(mx_aug - mn_aug) - 1


                ###Test Windows:
                wndws_test=np.empty((0,len(wndws1[0])), float)
                i=0
                windws=np.array([])
                for cls in range (1,cls_num+1):                                 #ساخت پنجره های داده های آموزش اصلی
                    vars()['wndws_tst'+str(cls)]=np.empty((0,len(wndws1[0])), float)
                    vars()['wndws_tst'+str(cls)]=np.append(vars()['wndws_tst'+str(cls)],vars()['ecg_tst'+str(cls)],axis=0)   

                # Normalization test windows
                for i in range (1,cls_num+1):                
                    cls=i
                    #print('\n cls', i, ' >> ')
                    #print('max magnitude class', i , ' = ' ,np.max(vars()['wndws_tst'+str(cls)][:,:-1]))
                    #print('min magnitude class', i , ' = ' ,np.min(vars()['wndws_tst'+str(cls)][:,:-1]))
                    vars()['wndws_tst'+str(i)][:,:-1]= 2*(vars()['wndws_tst'+str(i)][:,:-1]-mn_aug)/(mx_aug - mn_aug) - 1
                    #print('after normalizing >>')
                    #print('max magnitude class', i , ' = ' ,np.max(vars()['wndws_tst'+str(cls)][:,:-1]))
                    #print('min magnitude class', i , ' = ' ,np.min(vars()['wndws_tst'+str(cls)][:,:-1]))
                #print("each class and its windows =")                    #تجمیع کلاس های تست
                cls_wndws=np.array([])
                for cls in range (1,cls_num+1):                                # آرایه ی تعداد پنجره ی هر کلاس
                    wns=len(vars()['wndws_tst'+str(cls)])
                    cls_wndws=np.append(cls_wndws,wns)
                    #print(cls, wns, end='\t')
                    wndws_test=np.append(wndws_test,vars()['wndws_tst'+str(cls)],axis=0)
                mx_wndws=int(np.max(cls_wndws))                        # حداکثر تعداد پنجره ی موجود بین کلاس ها
                #print('\n max instance in classes of test windows =', mx_wndws)

                #print('min tst =', np.min(wndws_test[:,:-1]))
                #print('max tst =', np.max(wndws_test[:,:-1]))

                Xtest=wndws_test[:,:-1]
                ytest=np.int16(wndws_test[:,-1])

                #fullprint(ytest)

                trainx=np.random.permutation(xtrain)
                Xtrain=np.array(trainx[:,:-1])
                ytrain=np.int16(trainx[:,-1])

                X_train=np.array(Xtrain)
                y_train=np.array(ytrain)
                X_test=np.array(Xtest)
                y_test=np.array(ytest)
                X_valid=np.array(Xtrain)
                y_valid=np.array(ytrain)
                #print('X_train => ', X_train.shape)
                #print('y_train => ', y_train.shape)
                #print('X_test  => ', X_test.shape)
                #print('y_test  => ', y_test.shape)
                #print('X_valid  => ', X_valid.shape)
                #print('y_valid  => ', y_valid.shape)

                y_train_cat=to_categorical(y_train)
                y_valid_cat=to_categorical(y_valid)
                y_test_cat=to_categorical(y_test)
                X_train = np.expand_dims(X_train, axis=2)
                X_valid = np.expand_dims(X_valid, axis=2)
                X_test = np.expand_dims(X_test, axis=2)

                ####### NETWORK #######
                accuracy=0
                acc_crs=np.array([])
                ##for i in range (10):
                ##    if accuracy<0.2 :
                verbose, epochs, batch_size = 0, 1000, 10
                n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train_cat.shape[1]
                steps_per_epoch = len(X_train)//batch_size
                validation_steps = len(X_valid)//batch_size # if you have test data
                model_crs = Sequential()
                BatchNormalization()
                model_crs.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(n_timesteps,n_features)))
                #model_crs.add(MaxPooling1D(pool_size=3))
                BatchNormalization()
                model_crs.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
                #model_crs.add(Dropout(0.5))
                model_crs.add(MaxPooling1D(pool_size=3))
                BatchNormalization()
                model_crs.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
                model_crs.add(MaxPooling1D(pool_size=3))
                BatchNormalization()
                model_crs.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
                model_crs.add(MaxPooling1D(pool_size=3))
                BatchNormalization()
                model_crs.add(Conv1D(filters=256, kernel_size=3, activation='relu'))
                model_crs.add(MaxPooling1D(pool_size=3))
                '''model_crs.add(Conv1D(filters=512, kernel_size=3, activation='relu'))
                model_crs.add(MaxPooling1D(pool_size=3))
                model_crs.add(Conv1D(filters=1024, kernel_size=3, activation='relu'))
                model_crs.add(MaxPooling1D(pool_size=3))
                '''
                model_crs.add(Flatten())
                #model_crs.add(Dropout(0.5))
                model_crs.add(Dense(2000, activation='relu'))
                model_crs.add(Dense(n_outputs, activation='softmax'))
                model_crs.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
                # fit network   #CategoricalCrossentropy #sparse_categorical_crossentropy #SparseCategoricalCrossentropy
                earlystopping = callbacks.EarlyStopping(monitor ="val_accuracy", mode ="max", patience = 20, restore_best_weights = True)
                model_crs.fit(X_train, y_train_cat, epochs=epochs, batch_size=batch_size, verbose=verbose, validation_data = (X_valid, y_valid_cat), callbacks =[earlystopping])
                # evaluate model_crs
                _, accuracy = model_crs.evaluate(X_valid, y_valid_cat, batch_size=batch_size, verbose=verbose)
                #print('np.shape(X_test)=',np.shape(X_test))
                #model_crs.summary()
                predict_x=model_crs.predict(X_test)              # Function 1
                y_pred_crs=maxindx(predict_x)                    # function from augment.py to remove 0 index predictions
                
                rprt0=classification_report(y_test, y_pred_crs,output_dict=True)
                rprt_row=np.array([])
                rprt_row=np.append(rprt_row,rprt0['accuracy'])
                rprt_row=np.append(rprt_row,rprt0['macro avg']['f1-score'])
                rprt_row=np.append(rprt_row,rprt0['weighted avg']['f1-score'])
                rprt=np.append(rprt,[rprt_row],axis=0)
            maxm=rprt[np.argmax(rprt[:,1])]
            avrg=np.mean(rprt,axis=0)
            rslts=np.append(rslts,['mthd '+str(methd)+'  q '+str(quality)+'  Dist '+str(dp_slct_dstrb)+'  average= '+str(np.int16(100*avrg))+'  max= '+str(np.int16(100*maxm))+'  var= '+str(np.int16(np.var(100*rprt[:,1])))],axis=0)
# Out:
# 36/36 [==============================] - 0s 4ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step
# 36/36 [==============================] - 0s 2ms/step

# %%
rslts
# Out:
# array(['mthd 10  q 1  Dist 1  average= [97 97 97]  max= [98 98 98]  var= 6',
#        'mthd 10  q 1  Dist 2  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 10  q 1  Dist 3  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 10  q 1  Dist 4  average= [97 97 97]  max= [98 98 98]  var= 0',
#        'mthd 10  q 1  Dist 5  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 10  q 2  Dist 1  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 10  q 2  Dist 2  average= [97 97 97]  max= [99 99 99]  var= 3',
#        'mthd 10  q 2  Dist 3  average= [95 95 95]  max= [97 97 97]  var= 2',
#        'mthd 10  q 2  Dist 4  average= [96 96 96]  max= [98 98 98]  var= 4',
#        'mthd 10  q 2  Dist 5  average= [96 96 96]  max= [97 97 97]  var= 0',
#        'mthd 10  q 3  Dist 1  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 10  q 3  Dist 2  average= [96 96 96]  max= [98 98 98]  var= 6',
#        'mthd 10  q 3  Dist 3  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 10  q 3  Dist 4  average= [96 96 96]  max= [97 97 97]  var= 2',
#        'mthd 10  q 3  Dist 5  average= [97 97 97]  max= [98 98 98]  var= 1',
#        'mthd 10  q 4  Dist 1  average= [94 94 94]  max= [95 95 95]  var= 0',
#        'mthd 10  q 4  Dist 2  average= [95 95 95]  max= [98 98 98]  var= 4',
#        'mthd 10  q 4  Dist 3  average= [97 97 97]  max= [97 97 97]  var= 1',
#        'mthd 10  q 4  Dist 4  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 10  q 4  Dist 5  average= [94 94 94]  max= [97 97 97]  var= 6',
#        'mthd 10  q 5  Dist 1  average= [93 93 93]  max= [97 97 97]  var= 9',
#        'mthd 10  q 5  Dist 2  average= [95 95 95]  max= [97 97 97]  var= 3',
#        'mthd 10  q 5  Dist 3  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 10  q 5  Dist 4  average= [97 97 97]  max= [99 99 99]  var= 1',
#        'mthd 10  q 5  Dist 5  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 10  q 6  Dist 1  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 10  q 6  Dist 2  average= [96 96 96]  max= [97 97 97]  var= 5',
#        'mthd 10  q 6  Dist 3  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 10  q 6  Dist 4  average= [97 97 97]  max= [98 98 98]  var= 1',
#        'mthd 10  q 6  Dist 5  average= [97 97 97]  max= [98 98 98]  var= 2',
#        'mthd 20  q 1  Dist 1  average= [96 96 96]  max= [98 98 98]  var= 1',
#        'mthd 20  q 1  Dist 2  average= [97 97 97]  max= [97 97 97]  var= 0',
#        'mthd 20  q 1  Dist 3  average= [97 97 97]  max= [98 98 98]  var= 0',
#        'mthd 20  q 1  Dist 4  average= [97 97 97]  max= [99 99 99]  var= 0',
#        'mthd 20  q 1  Dist 5  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 20  q 2  Dist 1  average= [96 96 96]  max= [98 98 98]  var= 4',
#        'mthd 20  q 2  Dist 2  average= [97 97 97]  max= [98 98 98]  var= 0',
#        'mthd 20  q 2  Dist 3  average= [97 97 97]  max= [98 98 98]  var= 0',
#        'mthd 20  q 2  Dist 4  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 20  q 2  Dist 5  average= [97 97 97]  max= [97 97 97]  var= 0',
#        'mthd 20  q 3  Dist 1  average= [96 96 96]  max= [97 97 97]  var= 0',
#        'mthd 20  q 3  Dist 2  average= [97 97 97]  max= [97 97 97]  var= 0',
#        'mthd 20  q 3  Dist 3  average= [96 96 96]  max= [98 98 98]  var= 4',
#        'mthd 20  q 3  Dist 4  average= [97 97 97]  max= [98 98 98]  var= 0',
#        'mthd 20  q 3  Dist 5  average= [96 96 96]  max= [98 98 98]  var= 5',
#        'mthd 20  q 4  Dist 1  average= [96 96 96]  max= [97 97 97]  var= 0',
#        'mthd 20  q 4  Dist 2  average= [97 97 97]  max= [97 97 97]  var= 0',
#        'mthd 20  q 4  Dist 3  average= [95 95 95]  max= [97 97 97]  var= 2',
#        'mthd 20  q 4  Dist 4  average= [94 94 94]  max= [97 97 97]  var= 4',
#        'mthd 20  q 4  Dist 5  average= [94 94 94]  max= [97 97 97]  var= 4',
#        'mthd 20  q 5  Dist 1  average= [97 97 97]  max= [97 97 97]  var= 0',
#        'mthd 20  q 5  Dist 2  average= [96 96 96]  max= [98 98 98]  var= 1',
#        'mthd 20  q 5  Dist 3  average= [96 96 96]  max= [98 98 98]  var= 4',
#        'mthd 20  q 5  Dist 4  average= [97 97 97]  max= [98 98 98]  var= 0',
#        'mthd 20  q 5  Dist 5  average= [96 96 96]  max= [96 96 96]  var= 0',
#        'mthd 20  q 6  Dist 1  average= [97 97 97]  max= [98 98 98]  var= 0',
#        'mthd 20  q 6  Dist 2  average= [98 98 98]  max= [99 99 99]  var= 1',
#        'mthd 20  q 6  Dist 3  average= [97 97 97]  max= [97 97 97]  var= 0',
#        'mthd 20  q 6  Dist 4  average= [97 97 97]  max= [97 97 97]  var= 0',
#        'mthd 20  q 6  Dist 5  average= [97 97 97]  max= [99 99 99]  var= 1',
#        'mthd 30  q 1  Dist 1  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 1  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 1  Dist 3  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 1  Dist 4  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 1  Dist 5  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 2  Dist 1  average= [98 98 98]  max= [99 99 99]  var= 1',
#        'mthd 30  q 2  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 2  Dist 3  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 2  Dist 4  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 2  Dist 5  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 3  Dist 1  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 3  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 3  Dist 3  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 3  Dist 4  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 30  q 3  Dist 5  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 4  Dist 1  average= [98 98 98]  max= [99 99 99]  var= 1',
#        'mthd 30  q 4  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 4  Dist 3  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 4  Dist 4  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 4  Dist 5  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 5  Dist 1  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 5  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 5  Dist 3  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 5  Dist 4  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 5  Dist 5  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 6  Dist 1  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 6  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 6  Dist 3  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 6  Dist 4  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 30  q 6  Dist 5  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 40  q 1  Dist 1  average= [94 94 94]  max= [95 95 95]  var= 1',
#        'mthd 40  q 1  Dist 2  average= [94 94 94]  max= [96 96 96]  var= 2',
#        'mthd 40  q 1  Dist 3  average= [93 93 93]  max= [96 96 96]  var= 5',
#        'mthd 40  q 1  Dist 4  average= [93 93 93]  max= [97 97 97]  var= 5',
#        'mthd 40  q 1  Dist 5  average= [88 87 87]  max= [96 96 96]  var= 87',
#        'mthd 40  q 2  Dist 1  average= [89 89 89]  max= [98 98 98]  var= 47',
#        'mthd 40  q 2  Dist 2  average= [93 93 93]  max= [96 96 96]  var= 3',
#        'mthd 40  q 2  Dist 3  average= [90 89 89]  max= [95 95 95]  var= 17',
#        'mthd 40  q 2  Dist 4  average= [88 88 88]  max= [95 95 95]  var= 27',
#        'mthd 40  q 2  Dist 5  average= [93 93 93]  max= [98 98 98]  var= 18',
#        'mthd 40  q 3  Dist 1  average= [89 89 89]  max= [92 92 92]  var= 9',
#        'mthd 40  q 3  Dist 2  average= [89 89 89]  max= [96 96 96]  var= 26',
#        'mthd 40  q 3  Dist 3  average= [92 92 92]  max= [93 93 93]  var= 0',
#        'mthd 40  q 3  Dist 4  average= [96 96 96]  max= [97 97 97]  var= 0',
#        'mthd 40  q 3  Dist 5  average= [90 90 90]  max= [96 96 96]  var= 42',
#        'mthd 40  q 4  Dist 1  average= [91 91 91]  max= [95 95 95]  var= 16',
#        'mthd 40  q 4  Dist 2  average= [89 89 89]  max= [96 96 96]  var= 23',
#        'mthd 40  q 4  Dist 3  average= [92 92 92]  max= [95 95 95]  var= 4',
#        'mthd 40  q 4  Dist 4  average= [93 93 93]  max= [94 94 94]  var= 4',
#        'mthd 40  q 4  Dist 5  average= [90 90 90]  max= [95 95 95]  var= 13',
#        'mthd 40  q 5  Dist 1  average= [86 86 86]  max= [92 92 92]  var= 34',
#        'mthd 40  q 5  Dist 2  average= [91 91 91]  max= [92 92 92]  var= 0',
#        'mthd 40  q 5  Dist 3  average= [89 89 89]  max= [93 93 93]  var= 10',
#        'mthd 40  q 5  Dist 4  average= [89 89 89]  max= [96 96 96]  var= 28',
#        'mthd 40  q 5  Dist 5  average= [93 93 93]  max= [96 96 96]  var= 6',
#        'mthd 40  q 6  Dist 1  average= [92 92 92]  max= [98 98 98]  var= 18',
#        'mthd 40  q 6  Dist 2  average= [94 94 94]  max= [95 95 95]  var= 0',
#        'mthd 40  q 6  Dist 3  average= [95 95 95]  max= [97 97 97]  var= 6',
#        'mthd 40  q 6  Dist 4  average= [91 91 91]  max= [93 93 93]  var= 0',
#        'mthd 40  q 6  Dist 5  average= [94 94 94]  max= [94 94 94]  var= 0',
#        'mthd 50  q 1  Dist 1  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 1  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 1  Dist 3  average= [98 98 98]  max= [99 99 99]  var= 1',
#        'mthd 50  q 1  Dist 4  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 1  Dist 5  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 2  Dist 1  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 2  Dist 2  average= [97 97 97]  max= [98 98 98]  var= 1',
#        'mthd 50  q 2  Dist 3  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 2  Dist 4  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 2  Dist 5  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 3  Dist 1  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 3  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 3  Dist 3  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 3  Dist 4  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 3  Dist 5  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 4  Dist 1  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 4  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 4  Dist 3  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 4  Dist 4  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 4  Dist 5  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 5  Dist 1  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 5  Dist 2  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 5  Dist 3  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 50  q 5  Dist 4  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 5  Dist 5  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 50  q 6  Dist 1  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 50  q 6  Dist 2  average= [99 99 99]  max= [99 99 99]  var= 0',
#        'mthd 50  q 6  Dist 3  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 50  q 6  Dist 4  average= [98 98 98]  max= [98 98 98]  var= 0',
#        'mthd 50  q 6  Dist 5  average= [98 98 98]  max= [99 99 99]  var= 0',
#        'mthd 60  q 1  Dist 1  average= [91 91 91]  max= [96 96 96]  var= 10',
#        'mthd 60  q 1  Dist 2  average= [90 90 90]  max= [94 94 94]  var= 14',
#        'mthd 60  q 1  Dist 3  average= [94 94 94]  max= [97 97 97]  var= 7',
#        'mthd 60  q 1  Dist 4  average= [96 96 96]  max= [97 97 97]  var= 0',
#        'mthd 60  q 1  Dist 5  average= [95 95 95]  max= [96 96 96]  var= 0',
#        'mthd 60  q 2  Dist 1  average= [95 95 95]  max= [97 97 97]  var= 6',
#        'mthd 60  q 2  Dist 2  average= [94 94 94]  max= [95 95 95]  var= 0',
#        'mthd 60  q 2  Dist 3  average= [93 93 93]  max= [98 98 98]  var= 21',
#        'mthd 60  q 2  Dist 4  average= [93 93 93]  max= [95 95 95]  var= 8',
#        'mthd 60  q 2  Dist 5  average= [89 89 89]  max= [90 90 90]  var= 0',
#        'mthd 60  q 3  Dist 1  average= [96 96 96]  max= [98 98 98]  var= 2',
#        'mthd 60  q 3  Dist 2  average= [87 87 87]  max= [92 92 92]  var= 27',
#        'mthd 60  q 3  Dist 3  average= [95 95 95]  max= [97 97 97]  var= 4',
#        'mthd 60  q 3  Dist 4  average= [96 96 96]  max= [97 97 97]  var= 3',
#        'mthd 60  q 3  Dist 5  average= [96 96 96]  max= [96 96 96]  var= 0',
#        'mthd 60  q 4  Dist 1  average= [93 93 93]  max= [95 95 95]  var= 11',
#        'mthd 60  q 4  Dist 2  average= [93 93 93]  max= [98 98 98]  var= 29',
#        'mthd 60  q 4  Dist 3  average= [91 91 91]  max= [95 95 95]  var= 8',
#        'mthd 60  q 4  Dist 4  average= [90 90 90]  max= [97 97 97]  var= 93',
#        'mthd 60  q 4  Dist 5  average= [94 94 94]  max= [97 97 97]  var= 7',
#        'mthd 60  q 5  Dist 1  average= [95 95 95]  max= [96 96 96]  var= 0',
#        'mthd 60  q 5  Dist 2  average= [89 88 88]  max= [99 99 99]  var= 60',
#        'mthd 60  q 5  Dist 3  average= [94 94 94]  max= [98 98 98]  var= 22',
#        'mthd 60  q 5  Dist 4  average= [91 91 91]  max= [92 92 92]  var= 1',
#        'mthd 60  q 5  Dist 5  average= [92 92 92]  max= [95 95 95]  var= 4',
#        'mthd 60  q 6  Dist 1  average= [96 96 96]  max= [97 97 97]  var= 0',
#        'mthd 60  q 6  Dist 2  average= [97 97 97]  max= [97 97 97]  var= 0',
#        'mthd 60  q 6  Dist 3  average= [95 95 95]  max= [95 95 95]  var= 0',
#        'mthd 60  q 6  Dist 4  average= [93 93 93]  max= [96 96 96]  var= 10',
#        'mthd 60  q 6  Dist 5  average= [93 93 93]  max= [98 98 98]  var= 23',
#        'mthd 70  q 1  Dist 1  average= [87 87 87]  max= [93 93 93]  var= 27',
#        'mthd 70  q 1  Dist 2  average= [90 90 90]  max= [94 94 94]  var= 8',
#        'mthd 70  q 1  Dist 3  average= [92 92 92]  max= [95 95 95]  var= 24',
#        'mthd 70  q 1  Dist 4  average= [91 91 91]  max= [95 95 95]  var= 24',
#        'mthd 70  q 1  Dist 5  average= [90 89 89]  max= [95 95 95]  var= 24',
#        'mthd 70  q 2  Dist 1  average= [84 84 84]  max= [91 91 91]  var= 56',
#        'mthd 70  q 2  Dist 2  average= [90 89 89]  max= [97 97 97]  var= 55',
#        'mthd 70  q 2  Dist 3  average= [87 86 86]  max= [93 93 93]  var= 43',
#        'mthd 70  q 2  Dist 4  average= [89 89 89]  max= [92 92 92]  var= 12',
#        'mthd 70  q 2  Dist 5  average= [92 92 92]  max= [97 97 97]  var= 33',
#        'mthd 70  q 3  Dist 1  average= [92 92 92]  max= [95 95 95]  var= 7',
#        'mthd 70  q 3  Dist 2  average= [90 90 90]  max= [96 96 96]  var= 24',
#        'mthd 70  q 3  Dist 3  average= [92 92 92]  max= [97 97 97]  var= 30',
#        'mthd 70  q 3  Dist 4  average= [94 94 94]  max= [96 96 96]  var= 5',
#        'mthd 70  q 3  Dist 5  average= [96 96 96]  max= [96 96 96]  var= 0',
#        'mthd 70  q 4  Dist 1  average= [89 89 89]  max= [94 94 94]  var= 40',
#        'mthd 70  q 4  Dist 2  average= [93 93 93]  max= [96 96 96]  var= 10',
#        'mthd 70  q 4  Dist 3  average= [93 93 93]  max= [95 95 95]  var= 2',
#        'mthd 70  q 4  Dist 4  average= [93 93 93]  max= [96 96 96]  var= 26',
#        'mthd 70  q 4  Dist 5  average= [88 88 88]  max= [96 96 96]  var= 29',
#        'mthd 70  q 5  Dist 1  average= [92 92 92]  max= [97 97 97]  var= 21',
#        'mthd 70  q 5  Dist 2  average= [91 91 91]  max= [94 94 94]  var= 15',
#        'mthd 70  q 5  Dist 3  average= [91 91 91]  max= [96 96 96]  var= 11',
#        'mthd 70  q 5  Dist 4  average= [93 93 93]  max= [96 96 96]  var= 2',
#        'mthd 70  q 5  Dist 5  average= [95 95 95]  max= [96 96 96]  var= 4',
#        'mthd 70  q 6  Dist 1  average= [90 90 90]  max= [95 95 95]  var= 20',
#        'mthd 70  q 6  Dist 2  average= [91 91 91]  max= [93 93 93]  var= 1',
#        'mthd 70  q 6  Dist 3  average= [89 89 89]  max= [92 92 92]  var= 4',
#        'mthd 70  q 6  Dist 4  average= [93 93 93]  max= [96 96 96]  var= 4',
#        'mthd 70  q 6  Dist 5  average= [92 92 92]  max= [94 94 94]  var= 2'],
#       dtype='<U67')

# %%
np.savetxt(("Results_virgl.txt"),rslts,delimiter=',')
np.savetxt(("Results.csv"),rslts,delimiter='\n')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1432                 try:
# -> 1433                     v = format % tuple(row) + newline
#    1434                 except TypeError as e:
#
# TypeError: must be real number, not numpy.str_
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10784/1642535132.py in <module>
# ----> 1 np.savetxt(("Results_virgl.txt"),rslts,delimiter=',')
#       2 np.savetxt(("Results.csv"),rslts,delimiter='\n')
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1433                     v = format % tuple(row) + newline
#    1434                 except TypeError as e:
# -> 1435                     raise TypeError("Mismatch between array dtype ('%s') and "
#    1436                                     "format specifier ('%s')"
#    1437                                     % (str(X.dtype), format)) from e
#
# TypeError: Mismatch between array dtype ('<U67') and format specifier ('%.18e')
